# %%
import requests
from bs4 import BeautifulSoup

# %%
pokemonHomeURL = "https://bulbapedia.bulbagarden.net/wiki/List_of_Pok%C3%A9mon_by_name"

# %%
HTML_Content = requests.get(pokemonHomeURL)

# %%
soupObj = BeautifulSoup(HTML_Content.content, 'html5lib')
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# <ipython-input-34-e115f3176a81> in <module>
# ----> 1 soupObj = BeautifulSoup(HTML_Content.content, 'html5lib')
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/bs4/__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     241             builder_class = builder_registry.lookup(*features)
#     242             if builder_class is None:
# --> 243                 raise FeatureNotFound(
#     244                     "Couldn't find a tree builder with the features you "
#     245                     "requested: %s. Do you need to install a parser library?"
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html5lib. Do you need to install a parser library?

# %%
soupObj
# Out:
# on_by_index_number_(Generation_VIII)" title="List of Pokémon by index number (Generation VIII)">Generation VIII</a>
# </td></tr>
# <tr>
# <td colspan="2" height="1">
# </td></tr>
# <tr style="font-size: 90%;">
# <th style="background: #ddf; padding: 2px 15px;"> by other numbering systems
# </th>
# ...

# %%
soupObj.table
# Out:
#  colspan="2" style="text-align:center; background:#A8A878"> <a href="/wiki/Normal_(type)" title="Normal (type)"><span style="color:#FFFFFF">Normal</span></a>
# </td></tr>
# <tr style="background:#FFF;">
# <td style="font-family:monospace"> #065
# </td>
# <th> <span class="plainlinks"><a href="/wiki/Alakazam_(Pok%C3%A9mon)" title="065"><img alt="065" height="68" src="//cdn.bulbagarden.net/upload/4/41/065MS8.png" width="68"/></a></span>
# </th>
# <td> <a href="/wiki/Alakazam_(Pok%C3%A9mon)" title="Alakazam (Pokémon)">Alakazam</a>
# </td>
# <td colspan="2" style="text-align:center; background:#F85888"> <a href="/wiki/Psychic_(type)" title="Psychic (type)"><span style="color:#FFFFFF">Psychic</span></a>
# </td></tr>
# <tr style="background:#FFF;">
# <td style="font-family:monospace"> #869
# </td>
# <th> <span class="plainlinks"><a href="/wiki/Alcremie_(Pok%C3%A9mon)" title="869"><img alt="869" height="68" src="//cdn.bulbagarden.net/upload/9/98/869MS8.png" width="68"/></a></span>
# </th>
# ...
